# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading https://files.pythonhosted.org/packages/97/38/cadb2b79268c7f82f6b027bf0b2f68750aafc5c70b6e1bc46b357386e07b/lazypredict-0.2.9-py2.py3-none-any.whl
# Collecting lightgbm==2.3.1
#   Downloading https://files.pythonhosted.org/packages/1f/cb/a8ec24334c35a7d0c87b4e4e056bd2137573c7c1bd81c760b79a2f370254/lightgbm-2.3.1-py2.py3-none-win_amd64.whl (544kB)
# Collecting xgboost==1.1.1
#   Downloading https://files.pythonhosted.org/packages/29/31/580e1a2cd683fa219b272bd4f52540c987a5f4be5d28ed506a87c551667f/xgboost-1.1.1-py3-none-win_amd64.whl (54.4MB)
# Collecting numpy==1.19.1
#   Downloading https://files.pythonhosted.org/packages/df/cb/7af5de0a4068ce314e13074a4f86afada7fa86a095489bbc80f5dabd4156/numpy-1.19.1-cp37-cp37m-win_amd64.whl (12.9MB)
# Collecting click==7.1.2
#   Downloading https://files.pythonhosted.org/packages/d2/3d/fa76db83bf75c4f8d338c2fd15c8d33fdd7ad23a9b5e57eb6c5de26b430e/click-7.1.2-py2.py3-none-any.whl (82kB)
# Collecting six==1.15.0
#   Downloading https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Collecting tqdm==4.56.0
#   Downloading https://files.pythonhosted.org/packages/80/02/8f8880a4fd6625461833abcf679d4c12a44c76f9925f92bf212bb6cefaad/tqdm-4.56.0-py2.py3-none-any.whl (72kB)
# Collecting pytest==5.4.3
#   Downloading https://files.pythonhosted.org/packages/9f/f3/0a83558da436a081344aa6c8b85ea5b5f05071214106036ce341b7769b0b/pytest-5.4.3-py3-none-any.whl (248kB)
# Collecting scipy==1.5.4
#   Downloading https://files.pythonhosted.org/packages/0e/d2/1a6ec41bca8722b56aa779313391ee46595085d0ceefa49b5acd308c7a38/scipy-1.5.4-cp37-cp37m-win_amd64.whl (31.2MB)
# Collecting scikit-learn==0.23.1
#   Downloading https://files.pythonhosted.org/packages/70/8e/682770fc1da047bb56443150bfd8d87d850459cd7cc412a5311de3abaa4a/scikit_learn-0.23.1-cp37-cp37m-win_amd64.whl (6.8MB)
# Collecting joblib==1.0.0
#   Downloading https://files.pythonhosted.org/packages/34/5b/bd0f0fb5564183884d8e35b81d06d7ec06a20d1a0c8b4c407f1554691dce/joblib-1.0.0-py3-none-any.whl (302kB)
# Collecting pandas==1.0.5
#   Downloading https://files.pythonhosted.org/packages/da/90/44d5e0a5d42506d2e31544c8f44c54be88c2128f6fc482c01de29ecfb365/pandas-1.0.5-cp37-cp37m-win_amd64.whl (8.7MB)
# Collecting PyYAML==5.3.1
#   Downloading https://files.pythonhosted.org/packages/fb/aa/1a7ac452c52b93ab759d0b5b81c901ea122d95a5abf429decc660a44a2f1/PyYAML-5.3.1-cp37-cp37m-win_amd64.whl (216kB)
# Requirement already satisfied: wcwidth in c:\users\naruk\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.1.7)
# Requirement already satisfied: importlib-metadata>=0.12; python_version < "3.8" in c:\users\naruk\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.17)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\users\naruk\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (7.0.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\users\naruk\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.12.0)
# Requirement already satisfied: py>=1.5.0 in c:\users\naruk\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (1.8.0)
# Requirement already satisfied: atomicwrites>=1.0; sys_platform == "win32" in c:\users\naruk\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (1.3.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\naruk\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.4.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\naruk\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (21.4.0)
# Requirement already satisfied: packaging in c:\users\naruk\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (19.0)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/61/cf/6e354304bcb9c6413c4e02a747b600061c21d38ba51e7e544ac7bc66aecc/threadpoolctl-3.1.0-py3-none-any.whl
# Requirement already satisfied: pytz>=2017.2 in c:\users\naruk\anaconda3\lib\site-packages (from pandas==1.0.5->lazypredict) (2019.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\naruk\anaconda3\lib\site-packages (from pandas==1.0.5->lazypredict) (2.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\naruk\anaconda3\lib\site-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest==5.4.3->lazypredict) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\naruk\anaconda3\lib\site-packages (from packaging->pytest==5.4.3->lazypredict) (2.4.0)
# Installing collected packages: joblib, numpy, scipy, threadpoolctl, scikit-learn, lightgbm, xgboost, click, six, tqdm, pytest, pandas, PyYAML, lazypredict
#   Found existing installation: joblib 0.13.2
#     Uninstalling joblib-0.13.2:
#       Successfully uninstalled joblib-0.13.2
#   Found existing installation: numpy 1.16.5
#     Uninstalling numpy-1.16.5:
#       Successfully uninstalled numpy-1.16.5
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Found existing installation: scikit-learn 0.21.2
#     Uninstalling scikit-learn-0.21.2:
#       Successfully uninstalled scikit-learn-0.21.2
#   Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
#   Found existing installation: Click 7.0
#     Uninstalling Click-7.0:
#       Successfully uninstalled Click-7.0
#   Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Found existing installation: tqdm 4.32.1
#     Uninstalling tqdm-4.32.1:
#       Successfully uninstalled tqdm-4.32.1
#   Found existing installation: pytest 5.0.1
#     Uninstalling pytest-5.0.1:
#       Successfully uninstalled pytest-5.0.1
#   Found existing installation: pandas 1.2.3
#     Uninstalling pandas-1.2.3:
#       Successfully uninstalled pandas-1.2.3
#   Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# Successfully installed PyYAML-5.3.1 click-7.1.2 joblib-1.0.0 lazypredict-0.2.9 lightgbm-2.3.1 numpy-1.19.1 pandas-1.0.5 pytest-5.4.3 scikit-learn-0.23.1 scipy-1.5.4 six-1.15.0 threadpoolctl-3.1.0 tqdm-4.56.0 xgboost-1.1.1
# ERROR: astroid 2.2.5 requires typed-ast>=1.3.0; implementation_name == "cpython", which is not installed.
# ERROR: tsfresh 0.12.0 has requirement pandas<=0.23.4,>=0.20.3, but you'll have pandas 1.0.5 which is incompatible.
# ERROR: textract 1.6.3 has requirement six==1.12.0, but you'll have six 1.15.0 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.1 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement scipy==1.4.1, but you'll have scipy 1.5.4 which is incompatible.
# ERROR: requests-cache 0.7.5 has requirement pyyaml>=5.4, but you'll have pyyaml 5.3.1 which is incompatible.
# ERROR: kaggle 1.5.6 has requirement urllib3<1.25,>=1.21.1, but you'll have urllib3 1.26.9 which is incompatible.
# ERROR: cirq 0.8.0 has requirement protobuf==3.8.0, but you'll have protobuf 3.13.0 which is incompatible.
# ERROR: chatterbot-corpus 1.2.0 has requirement PyYAML<4.0,>=3.12, but you'll have pyyaml 5.3.1 which is incompatible.
# ERROR: botocore 1.13.18 has requirement python-dateutil<2.8.1,>=2.1; python_version >= "2.7", but you'll have python-dateutil 2.8.2 which is incompatible.
# ERROR: botocore 1.13.18 has requirement urllib3<1.26,>=1.20; python_version >= "3.4", but you'll have urllib3 1.26.9 which is incompatible.

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop ('pIC50', axis=1)
Y = df.pIC50

# %%
X.shape
# Out:
# (4695, 881)

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1- .8)))
X= selection.fit_transform(X)
X.shape
# Out:
# (4695, 137)

# %%
X_train, X_test, Y_train, Y_test = train_test_split (X, Y, test_size=0.2)

# %%
clf =LazyRegressor (verbose=0, ignore_warnings=True)
train, test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
#  12%|█████████▉                                                                         | 5/42 [00:01<00:08,  4.31it/s]C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9770194381344481, tolerance: 0.7291358241674296
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0530253657971116, tolerance: 0.7291358241674296
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2157824587911819, tolerance: 0.7291358241674296
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.6941177278376927, tolerance: 0.7291358241674296
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.357685749975644, tolerance: 0.7291358241674296
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.659180544527771, tolerance: 0.7291358241674296
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.470631727645923, tolerance: 0.7291358241674296
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.705250953456925, tolerance: 0.7291358241674296
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.701879073576492, tolerance: 0.7291358241674296
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8574084733427298, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9343471131251135, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.848614512835411, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8706567485769483, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9813233652330382, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0524714092025533, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7552740861947314, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7760450553214469, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7341577815122946, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7336801506307893, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.750245132215241, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7682237575190811, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7700298771997041, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7976495318680463, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8414824466335631, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8628535307643688, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9209664544569023, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9841372311575469, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0650921152700903, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.104846171682766, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.454769160523938, tolerance: 0.7247386750422269
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0671086939482848, tolerance: 0.7036591604345734
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2114737901174522, tolerance: 0.7036591604345734
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8121160867958679, tolerance: 0.7036591604345734
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7721850204197835, tolerance: 0.7036591604345734
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.933014335716507, tolerance: 0.7036591604345734
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.152636285482913, tolerance: 0.7036591604345734
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.369091099832076, tolerance: 0.7036591604345734
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7842009496316678, tolerance: 0.7036591604345734
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.246918838870442, tolerance: 0.7036591604345734
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.053077757356732, tolerance: 0.7036591604345734
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.045048218163174, tolerance: 0.7036591604345734
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.3110454976558685, tolerance: 0.7036591604345734
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2325024419405963, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0137291612236368, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0196514305143864, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0372213769733207, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0507638251492608, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1252360364178458, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9513869516731575, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0896534485154916, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8137174676166978, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0679879361014173, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2558146597821178, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3975844862134181, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4838287553984628, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8184085394459544, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9644481771720166, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3431523091740019, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6900868244865705, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.002036928764028, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.2269154696568876, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.3902377999611417, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.312785012434688, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.780669323220536, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.1181505882077545, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52.845490683219396, tolerance: 0.9007182859600413
#   positive)
#  33%|███████████████████████████▎                                                      | 14/42 [00:19<00:57,  2.05s/it]C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
#  40%|█████████████████████████████████▏                                                | 17/42 [00:22<00:34,  1.40s/it]C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 63 iterations, i.e. alpha=2.560e-04, with an active set of 59 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 81 iterations, i.e. alpha=1.755e-04, with an active set of 75 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 82 iterations, i.e. alpha=1.630e-04, with an active set of 76 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 125 iterations, i.e. alpha=4.071e-05, with an active set of 116 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 127 iterations, i.e. alpha=3.428e-05, with an active set of 118 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 132 iterations, i.e. alpha=2.883e-05, with an active set of 122 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 139 iterations, i.e. alpha=1.292e-05, with an active set of 128 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 139 iterations, i.e. alpha=1.288e-05, with an active set of 128 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 139 iterations, i.e. alpha=1.146e-05, with an active set of 128 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 139 iterations, i.e. alpha=1.059e-05, with an active set of 128 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 142 iterations, i.e. alpha=5.699e-06, with an active set of 130 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 142 iterations, i.e. alpha=5.135e-06, with an active set of 130 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 142 iterations, i.e. alpha=2.953e-06, with an active set of 130 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 142 iterations, i.e. alpha=2.953e-06, with an active set of 130 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 142 iterations, i.e. alpha=2.953e-06, with an active set of 130 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 143 iterations, i.e. alpha=1.301e-06, with an active set of 131 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 143 iterations, i.e. alpha=1.301e-06, with an active set of 131 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 143 iterations, i.e. alpha=1.301e-06, with an active set of 131 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
#  43%|███████████████████████████████████▏                                              | 18/42 [00:22<00:25,  1.08s/it]C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 107 iterations, i.e. alpha=1.885e-04, with an active set of 93 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=1.701e-04, with an active set of 100 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 142 iterations, i.e. alpha=7.327e-05, with an active set of 124 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 144 iterations, i.e. alpha=6.499e-05, with an active set of 125 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 145 iterations, i.e. alpha=4.629e-05, with an active set of 126 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 145 iterations, i.e. alpha=4.218e-05, with an active set of 126 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 146 iterations, i.e. alpha=2.867e-05, with an active set of 127 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 146 iterations, i.e. alpha=2.834e-05, with an active set of 127 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 146 iterations, i.e. alpha=7.207e-06, with an active set of 127 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 148 iterations, i.e. alpha=5.065e-06, with an active set of 129 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 148 iterations, i.e. alpha=5.065e-06, with an active set of 129 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 149 iterations, i.e. alpha=2.625e-06, with an active set of 130 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 149 iterations, i.e. alpha=2.625e-06, with an active set of 130 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 149 iterations, i.e. alpha=2.367e-06, with an active set of 130 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 149 iterations, i.e. alpha=2.222e-06, with an active set of 130 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 149 iterations, i.e. alpha=2.222e-06, with an active set of 130 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 149 iterations, i.e. alpha=1.577e-06, with an active set of 130 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 149 iterations, i.e. alpha=8.465e-07, with an active set of 130 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 142 iterations, i.e. alpha=2.375e-05, with an active set of 128 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 144 iterations, i.e. alpha=1.935e-05, with an active set of 130 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 144 iterations, i.e. alpha=1.169e-05, with an active set of 130 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 144 iterations, i.e. alpha=4.400e-06, with an active set of 130 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 145 iterations, i.e. alpha=3.930e-06, with an active set of 131 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 145 iterations, i.e. alpha=3.930e-06, with an active set of 131 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 145 iterations, i.e. alpha=4.095e-07, with an active set of 131 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 145 iterations, i.e. alpha=4.095e-07, with an active set of 131 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 55 iterations, i.e. alpha=5.316e-04, with an active set of 50 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 61 iterations, i.e. alpha=4.305e-04, with an active set of 55 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 91 iterations, i.e. alpha=2.498e-04, with an active set of 81 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 91 iterations, i.e. alpha=2.357e-04, with an active set of 81 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=1.491e-04, with an active set of 100 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 118 iterations, i.e. alpha=1.210e-04, with an active set of 106 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 121 iterations, i.e. alpha=1.107e-04, with an active set of 109 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 136 iterations, i.e. alpha=3.897e-05, with an active set of 124 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 138 iterations, i.e. alpha=3.128e-05, with an active set of 126 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 138 iterations, i.e. alpha=2.868e-05, with an active set of 126 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 139 iterations, i.e. alpha=2.131e-05, with an active set of 127 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 139 iterations, i.e. alpha=1.944e-05, with an active set of 127 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 139 iterations, i.e. alpha=1.277e-05, with an active set of 127 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 141 iterations, i.e. alpha=1.422e-05, with an active set of 128 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 141 iterations, i.e. alpha=6.529e-06, with an active set of 128 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 141 iterations, i.e. alpha=6.529e-06, with an active set of 128 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 141 iterations, i.e. alpha=5.199e-06, with an active set of 128 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 141 iterations, i.e. alpha=5.199e-06, with an active set of 128 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 143 iterations, i.e. alpha=8.628e-07, with an active set of 130 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 143 iterations, i.e. alpha=8.628e-07, with an active set of 130 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 143 iterations, i.e. alpha=8.628e-07, with an active set of 130 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 143 iterations, i.e. alpha=5.250e-07, with an active set of 130 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=2.198e-04, with an active set of 67 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 76 iterations, i.e. alpha=1.725e-04, with an active set of 74 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 76 iterations, i.e. alpha=1.725e-04, with an active set of 74 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 83 iterations, i.e. alpha=1.223e-04, with an active set of 79 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 108 iterations, i.e. alpha=8.298e-05, with an active set of 101 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 129 iterations, i.e. alpha=4.426e-05, with an active set of 117 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 129 iterations, i.e. alpha=4.426e-05, with an active set of 117 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 129 iterations, i.e. alpha=4.346e-05, with an active set of 117 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 131 iterations, i.e. alpha=3.865e-05, with an active set of 119 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 138 iterations, i.e. alpha=3.617e-05, with an active set of 123 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# ...
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9670312868765905, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9633359651852516, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9267633332246987, tolerance: 0.7256072984246668
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.544546996592544, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.899020052696869, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.994153150451893, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.634384971835061, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.072893509067399, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.328490668725863, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.32588873012719, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.222093465865328, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.038744027360735, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.017787821023376, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.943065432314143, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.857410488991263, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.77008148546156, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.686041210717121, tolerance: 0.7197267743106547
#   tol, rng, random, positive)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.882519899209001, tolerance: 0.9007182859600413
#   positive)
#  50%|█████████████████████████████████████████                                         | 21/42 [00:25<00:20,  1.05it/s]C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 96 iterations, i.e. alpha=8.982e-05, with an active set of 84 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=5.411e-05, with an active set of 96 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=5.411e-05, with an active set of 96 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 137 iterations, i.e. alpha=3.282e-05, with an active set of 109 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 144 iterations, i.e. alpha=2.705e-05, with an active set of 112 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 144 iterations, i.e. alpha=2.656e-05, with an active set of 112 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 148 iterations, i.e. alpha=2.045e-05, with an active set of 116 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:603: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 154 iterations, alpha=1.903e-05, previous alpha=1.039e-05, with an active set of 121 regressors.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 91 iterations, i.e. alpha=1.071e-04, with an active set of 81 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 93 iterations, i.e. alpha=9.878e-05, with an active set of 83 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:603: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 100 iterations, alpha=8.032e-05, previous alpha=8.004e-05, with an active set of 87 regressors.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=2.188e-04, with an active set of 60 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 86 iterations, i.e. alpha=1.221e-04, with an active set of 72 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=7.555e-05, with an active set of 84 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:603: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 99 iterations, alpha=7.634e-05, previous alpha=6.943e-05, with an active set of 84 regressors.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 62 iterations, i.e. alpha=2.986e-04, with an active set of 58 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 80 iterations, i.e. alpha=1.777e-04, with an active set of 74 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:603: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 86 iterations, alpha=1.604e-04, previous alpha=1.586e-04, with an active set of 79 regressors.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 87 iterations, i.e. alpha=1.006e-04, with an active set of 81 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 100 iterations, i.e. alpha=5.904e-05, with an active set of 94 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=5.209e-05, with an active set of 98 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 107 iterations, i.e. alpha=4.783e-05, with an active set of 101 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 107 iterations, i.e. alpha=4.575e-05, with an active set of 101 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:603: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 109 iterations, alpha=4.971e-05, previous alpha=4.470e-05, with an active set of 102 regressors.
#   ConvergenceWarning)
#  55%|████████████████████████████████████████████▉                                     | 23/42 [00:25<00:12,  1.53it/s]C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 144 iterations, i.e. alpha=1.420e-05, with an active set of 118 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:577: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 144 iterations, i.e. alpha=1.420e-05, with an active set of 118 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py:603: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 146 iterations, alpha=1.331e-05, previous alpha=1.238e-05, with an active set of 119 regressors.
#   ConvergenceWarning)
#  60%|████████████████████████████████████████████████▊                                 | 25/42 [00:25<00:07,  2.21it/s]C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
#  62%|██████████████████████████████████████████████████▊                               | 26/42 [00:26<00:07,  2.08it/s]C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:46<00:00,  1.11s/it]

# %%
train
# Out:
#                                         Adjusted R-Squared                    R-Squared            RMSE  Time Taken
# Model
# HistGradientBoostingRegressor                         0.45                         0.53            1.07        3.68
# LGBMRegressor                                         0.45                         0.53            1.07        0.37
# XGBRegressor                                          0.42                         0.50            1.10        1.65
# RandomForestRegressor                                 0.41                         0.50            1.11        3.59
# SVR                                                   0.41                         0.50            1.11        2.87
# NuSVR                                                 0.41                         0.49            1.12        2.29
# BaggingRegressor                                      0.37                         0.46            1.15        0.46
# MLPRegressor                                          0.35                         0.45            1.17        8.19
# KNeighborsRegressor                                   0.34                         0.44            1.17        0.67
# GradientBoostingRegressor                             0.31                         0.41            1.21        1.61
# Ridge                                                 0.21                         0.32            1.29        0.06
# RidgeCV                                               0.21                         0.32            1.29        0.10
# ElasticNetCV                                          0.20                         0.32            1.30        1.92
# LassoCV                                               0.20                         0.32            1.30        1.99
# HuberRegressor                                        0.20                         0.31            1.30        1.07
# LassoLarsCV                                           0.19                         0.31            1.30        0.30
# LassoLarsIC                                           0.19                         0.31            1.31        0.09
# LinearSVR                                             0.19                         0.31            1.31        0.59
# BayesianRidge                                         0.18                         0.30            1.31        0.15
# SGDRegressor                                          0.17                         0.29            1.32        0.07
# ExtraTreesRegressor                                   0.16                         0.29            1.33        5.14
# PoissonRegressor                                      0.13                         0.26            1.35        0.09
# DecisionTreeRegressor                                 0.12                         0.25            1.36        0.09
# ExtraTreeRegressor                                    0.11                         0.24            1.36        0.11
# OrthogonalMatchingPursuit                             0.08                         0.21            1.39        0.06
# OrthogonalMatchingPursuitCV                           0.08                         0.21            1.39        0.13
# GammaRegressor                                        0.06                         0.20            1.40        0.08
# TweedieRegressor                                      0.06                         0.20            1.40        0.05
# GeneralizedLinearRegressor                            0.06                         0.20            1.40        0.09
# LarsCV                                                0.06                         0.20            1.41        0.39
# AdaBoostRegressor                                     0.02                         0.16            1.43        1.06
# LinearRegression                                     -0.13                         0.03            1.54        0.10
# TransformedTargetRegressor                           -0.13                         0.03            1.54        0.08
# Lars                                                 -0.16                         0.01            1.56        0.22
# Lasso                                                -0.17                        -0.00            1.57        0.09
# ElasticNet                                           -0.17                        -0.00            1.57        0.06
# DummyRegressor                                       -0.17                        -0.00            1.57        0.03
# LassoLars                                            -0.17                        -0.00            1.57        0.05
# PassiveAggressiveRegressor                           -0.29                        -0.10            1.64        0.07
# GaussianProcessRegressor                             -6.27                        -5.21            3.91        5.22
# KernelRidge                                         -15.96                       -13.48            5.97        0.98
# RANSACRegressor               -143226746979984011689984.00 -122307701845380799922176.00 548372870807.91        0.68

# %%
test
# Out:
#                                         Adjusted R-Squared                    R-Squared            RMSE  Time Taken
# Model
# HistGradientBoostingRegressor                         0.45                         0.53            1.07        3.68
# LGBMRegressor                                         0.45                         0.53            1.07        0.37
# XGBRegressor                                          0.42                         0.50            1.10        1.65
# RandomForestRegressor                                 0.41                         0.50            1.11        3.59
# SVR                                                   0.41                         0.50            1.11        2.87
# NuSVR                                                 0.41                         0.49            1.12        2.29
# BaggingRegressor                                      0.37                         0.46            1.15        0.46
# MLPRegressor                                          0.35                         0.45            1.17        8.19
# KNeighborsRegressor                                   0.34                         0.44            1.17        0.67
# GradientBoostingRegressor                             0.31                         0.41            1.21        1.61
# Ridge                                                 0.21                         0.32            1.29        0.06
# RidgeCV                                               0.21                         0.32            1.29        0.10
# ElasticNetCV                                          0.20                         0.32            1.30        1.92
# LassoCV                                               0.20                         0.32            1.30        1.99
# HuberRegressor                                        0.20                         0.31            1.30        1.07
# LassoLarsCV                                           0.19                         0.31            1.30        0.30
# LassoLarsIC                                           0.19                         0.31            1.31        0.09
# LinearSVR                                             0.19                         0.31            1.31        0.59
# BayesianRidge                                         0.18                         0.30            1.31        0.15
# SGDRegressor                                          0.17                         0.29            1.32        0.07
# ExtraTreesRegressor                                   0.16                         0.29            1.33        5.14
# PoissonRegressor                                      0.13                         0.26            1.35        0.09
# DecisionTreeRegressor                                 0.12                         0.25            1.36        0.09
# ExtraTreeRegressor                                    0.11                         0.24            1.36        0.11
# OrthogonalMatchingPursuit                             0.08                         0.21            1.39        0.06
# OrthogonalMatchingPursuitCV                           0.08                         0.21            1.39        0.13
# GammaRegressor                                        0.06                         0.20            1.40        0.08
# TweedieRegressor                                      0.06                         0.20            1.40        0.05
# GeneralizedLinearRegressor                            0.06                         0.20            1.40        0.09
# LarsCV                                                0.06                         0.20            1.41        0.39
# AdaBoostRegressor                                     0.02                         0.16            1.43        1.06
# LinearRegression                                     -0.13                         0.03            1.54        0.10
# TransformedTargetRegressor                           -0.13                         0.03            1.54        0.08
# Lars                                                 -0.16                         0.01            1.56        0.22
# Lasso                                                -0.17                        -0.00            1.57        0.09
# ElasticNet                                           -0.17                        -0.00            1.57        0.06
# DummyRegressor                                       -0.17                        -0.00            1.57        0.03
# LassoLars                                            -0.17                        -0.00            1.57        0.05
# PassiveAggressiveRegressor                           -0.29                        -0.10            1.64        0.07
# GaussianProcessRegressor                             -6.27                        -5.21            3.91        5.22
# KernelRidge                                         -15.96                       -13.48            5.97        0.98
# RANSACRegressor               -143226746979984011689984.00 -122307701845380799922176.00 548372870807.91        0.68

# %%
#bar plot of R-squared Values
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(5, 10))
#sns.set_theme(style='whitegrid')
ax = sns.barplot(y=train.index, x='R-Squared', data=train)
ax.set(xlim=(0, 1))
# Out:
# [(0, 1)]

# %%
#bar plot of RMSE Values
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(5, 10))
#sns.set_theme(style='whitegrid')
ax = sns.barplot(y=train.index, x='RMSE', data=train)
ax.set (xlim=(0, 10))
# Out:
# [(0, 10)]

# %%
#bar plot of caliculation time
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(5, 10))
#sns.set_theme(style='whitegrid')
ax = sns.barplot(y=train.index, x='Time Taken', data=train)
ax.set (xlim=(0, 10))
# Out:
# [(0, 10)]

# %%
finished
